# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("filteredsouthwark.csv", usecols=[1,2,3,7,10])

# %%
df.head(50)
# Out:
#    Title Number     Tenure                                   Property Address  \
# 0     TGL266222   Freehold  St Gertrudes RC Church and 1 Debnams Road, Sou...
# 1     TGL266229  Leasehold        Flat 1, 374 Old Kent Road, London (SE1 5AA)
# 2     TGL266266  Leasehold             Warehouse F, Winchester Square, London
# 3     TGL266443   Freehold                     Land at Fulford Street, London
# 4     TGL266916  Leasehold                  238 Olney Road, London (SE17 3HU)
# 5     TGL267088   Freehold                    land at Galleywall Road, London
# 6     TGL267792  Leasehold  Flat 14, Aylesford House, Long Lane, London (S...
# 7     TGL268016   Freehold  Land on the North side of Crampton Street, London
# 8     TGL268066  Leasehold                145 Jamaica Road, London (SE16 4SH)
# 9     TGL231308  Leasehold  Unit D, Cube House, 5 Spa Road, London (SE16 3GD)
# 10    TGL231632  Leasehold       Health Club, 2 More London Riverside, London
# ...

# %%
dfpeabody = df[df['Proprietor Name (1)'] == 'PEABODY TRUST']

# %%
dfpeabody
# Out:
#       Title Number     Tenure  \
# 45       TGL250165  Leasehold
# 46       TGL250167  Leasehold
# 47       TGL250172  Leasehold
# 48       TGL250183  Leasehold
# 59       TGL257940   Freehold
# ...            ...        ...
# 18563    TGL250166  Leasehold
# 18746    TGL215646   Freehold
# 18801    SGL142008   Freehold
# 19035    TGL312065   Freehold
# 19079    TGL313256  Leasehold
#
#                                         Property Address  Postcode  \
# 45     Apartment 2, Galleria Court, Sumner Road, Lond...  SE15 6PW
# 46     Flat 3, Castle House, Sumner Road, London (SE1...  SE15 6LA
# 47     Flat 8, Castle House, Sumner Road, London (SE1...  SE15 6LA
# 48     Flat 63, Castle House, Sumner Road, London (SE...  SE15 6LA
# 59     1, 3 & 5, Seth Street and 59 and 63 Swan Road,...       NaN
# ...                                                  ...       ...
# 18563  Flat 2, Castle House, Sumner Road, London (SE1...  SE15 6LA
# ...

# %%
dfLDD = pd.read_csv("http://35percent.org/img/LDD_Southwark.csv")

# %%
dfLDD.head(40)
# Out:
#            ref          Permission Type  \
# 0   09-AP-0519  Details/Reserve Matters
# 1   04-AP-0190                     Full
# 2   05-AP-1949                  Outline
# 3   07-AP-0760                     Full
# 4   09-AP-1870                     Full
# 5   06-AP-0323                     Full
# 6   07-CO-0046                  Outline
# 7   03-AP-1228                     Full
# 8   06-AP-0374                     Full
# 9   04-AP-0772                     Full
# 10  07-AP-2801                     Full
# 11  05-AP-2502                     Full
# 12  03-AP-2113                     Full
# 13  09-AP-2388                     Full
# 14  07-AP-1304                     Full
# 15  14-AP-1862                     Full
# 16  11-AP-2565                     Full
# 17  11-AP-4309                     Full
# 18  12-AP-1455                     Full
# 19  03-AP-1044                     Full
# 20  06-AP-0141                     Full
# 21  15-AP-1330                     Full
# ...
